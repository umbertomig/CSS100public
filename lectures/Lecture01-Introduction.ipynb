# %% [markdown]
# # CSS 100
#
# ## Advanced Python Programming
#
# ### Dr. Umberto Mignozzetti (CSS / POLI)

# %% [markdown]
# ## CSS 100
#
# XXXX what going to learn
#
# ## CSS 100
#
# XXXX Four things you are going to be able to do
#
# ## CSS 100
#
# XXXX Course Plan
#
# XXXX Day 01
# XXXX Day 02 etc
#
# ## CSS 100
#
# XXXX Labs Plan
#
# XXXX Lab 01
# XXXX Lab 02 etc
#
# ## CSS 100
#
# XXXX Books and Resources
#
# XXXX
#
# ## CSS 100
#
# XXXX Bureaucracy
#
# XXXX Assignments: Weekly Assignments (easy)
#
# ## CSS 100
#
# XXXX Bureaucracy
#
# XXXX Assignments: Problem Sets (hard)
#
# ## CSS 100
#
# XXXX Bureaucracy
#
# XXXX Assignments: Final Exam (hard)
#
# ## CSS 100
#
# XXXX Bureaucracy
#
# XXXX Grading: All graded for correctness
#
# - No points for effort: Effort is relevant in CSS 001 and CSS 002. In here, you need to get it right.
#
# ## CSS 100
#
# XXXX Bureaucracy
#
# XXXX Who am I?
#
# ## CSS 100
#
# XXXX Bureaucracy
#
# XXXX Who are you?
#
#
# ## CSS 100
#
# XXXX Bureaucracy
#
# XXXX Help: We are here to help!
#
# XXXX:
# - My office hours: XXXX
# - Link: XXXX
#
# XXXX:
# - My office hours: XXXX
# - Link: XXXX
#
# ## CSS 100
#
# XXXX University Resources
#
# XXXX
#
# ## CSS 100
#
# XXXX Datahub
#
# ## CSS 100
#
# XXXX Datahub boost
#
# ## CSS 100
#
# XXXX Datahub boost
#
# ## CSS 100
#
# XXXX Datahub boost
#
# ## CSS 100
#
# XXXX Go pro: just install Anaconda in your comp.
#
# ## CSS 100
#
# XXXX Go pro: just install Anaconda in your comp.
#
# ## CSS 100
#
# Final
#
# ## Questions?
#
# ## See you in the next class
